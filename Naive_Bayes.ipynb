# %% [markdown]
# given some sample of data in which we find some features. which can be represented as x(the data) in an array (the features). the array would be like
#
# `x1,x2,x3,x4` where each number is a new feature(column) in the code/database
#
# ## Model Arch
# ![ALT text](/Users/chandlermason/learning_code/Machine_Learning/Pictures/Bayes_Model.png)
#
#
# NOTES:
# **This model is a classifier**
# This means that it is trained using labeled data. This is done to understand the probability distribution of the features given each class. **we must have the distribution and stats on each item before we move on to classification.**
#
#
# ## Terms
#
# **Instance:** like a sample. it's one user. We think of an instance as WHO, its like any dataset -> the row
#
# **Feature/Predictor:** a column (or array) used as input. The feature value is what a specific Instance has for that feature. (it's the cell in excel docs)
#
# **Target:** Also called hte label, class label, response variable, dependednt variable. This is the thing we are trying to predict
#
# **Class:** a possible value the **target** can take. For instance in a binary class we can have Y or N. it's just the possible values of the target
#
#
# You find the Probability P() of your Predictor or Class.

# %%
import numpy as np

# this is the training data for our classification problem

# here we have 4 Instances (training examples), with each feature being a movie
# if a person watches a movie they get a 1, otherwise 0
# we then are trying to predict if they will like a new movie (Y/N) 

# each row is a training example, each column is a feature
#writing the array into a list of list
x_train = np.array([
    [0,1,1],
    [0,0,1],
    [0,0,0],
    [1,1,0]])

# the target variable for each training example
Y_train = ['Y','N','Y','Y']

X_Test = np.array([[1,1,0]])

# %% [markdown]
# Make sure to pay attention to the code example below

# %%
# start with the prior
# group by label and record the index (indiced) by the class (Y/N)

def get_label_indicies(labels):
    """
    Group the samples based on their labels and return the index
    @param labels: list of labels (classes) 
    @return: dict, {class1:[indices],class2,indices]}
    """

from collections import defaultdict
